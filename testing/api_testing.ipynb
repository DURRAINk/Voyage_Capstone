# %% [markdown]
# # APIs are tested here

# %% [markdown]
# ## importing Libraries

# %%
import requests

# %% [markdown]
# ## Price Prediction API testing

# %%
url = "http://127.0.0.1:5000/predict_price"
payload = {
    "from": "Brasilia (DF)",
    "to": "Florianopolis (SC)",
    "agency": "CloudFy",
    "flightType": "economic"}
response = requests.post(url, json=payload)
print('Status code:', response.status_code)
print('Response headers:', response.headers)
print('Response text:', response.text)
try:
    print('JSON:', response.json())
except ValueError:
    print('Response is not valid JSON')
# Out:
# Status code: 200
# Response headers: {'Server': 'Werkzeug/3.0.2 Python/3.12.3', 'Date': 'Tue, 10 Feb 2026 12:20:49 GMT', 'Content-Type': 'application/json', 'Content-Length': '43', 'Connection': 'close'}
# Response text: {
#   "predicted_price": 884.9399999999825
# }
#
# JSON: {'predicted_price': 884.9399999999825}

# %% [markdown]
# ## Hotel Recommendation API testing

# %%
url = "http://127.0.0.1:5000/recommend_hotel"
payload = {'place': 'Sao Paulo (SP)', 'days': 3}
response = requests.post(url, json=payload)
print('Status code:', response.status_code)
print('Response headers:', response.headers)
print('Response text:', response.text)
try:
    print('JSON:', response.json())
except ValueError:
    print('Response is not valid JSON')
# Out:
# Status code: 200
# Response headers: {'Server': 'Werkzeug/3.0.2 Python/3.12.3', 'Date': 'Tue, 10 Feb 2026 12:51:45 GMT', 'Content-Type': 'application/json', 'Content-Length': '38', 'Connection': 'close'}
# Response text: {
#   "recommended_hotel": "Hotel AF"
# }
#
# JSON: {'recommended_hotel': 'Hotel AF'}

# %% [markdown]
# ## Gender Classification API testing

# %%
url = "http://127.0.0.1:5000/classify_gender"
payload = {'name_x': 'Hotel AF', 'place': 'Sao Paulo (SP)', 'days': 3, 'company': '4You', 'age': 46}
response = requests.post(url, json=payload)
print('Status code:', response.status_code)
print('Response headers:', response.headers)
print('Response text:', response.text)
try:
    print('JSON:', response.json())
except ValueError:
    print('Response is not valid JSON')
# Out:
# Status code: 200
# Response headers: {'Server': 'Werkzeug/3.0.2 Python/3.12.3', 'Date': 'Tue, 10 Feb 2026 12:57:35 GMT', 'Content-Type': 'application/json', 'Content-Length': '34', 'Connection': 'close'}
# Response text: {
#   "classified_gender": "none"
# }
#
# JSON: {'classified_gender': 'none'}

# %%
url = "http://127.0.0.1:5000/predict_price"
payload = {
    "from": "Brasilia (DF)",
    "to": "Florianopolis (SC)",
    "agency": "CloudFy",
    "flightType": "economic"}
response = requests.post(url, json=payload)
print('Status code:', response.status_code)
print('Response headers:', response.headers)
print('Response text:', response.text)
try:
    print('JSON:', response.json())
except ValueError:
    print('Response is not valid JSON')
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# ...
